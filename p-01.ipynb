# %%
#import the necessary packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Take the Dataset

# %%
file="E:\\DOWNLOADS\\train_ctrUa4K.csv"
loan_ds=pd.read_csv(file)
loan_ds
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_ds.info()        #Gives the informatiom about the Dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_ds.head()     # Gives the top 5 rows of the dataframe
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_ds.tail()     #gives the last 5 rows of the dataframe
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_ds.shape     #gives the rows and columns
# Out:
# (614, 13)

# %%
loan_ds.size   # total count of observations in the dataframe (614*13)
# Out:
# 7982

# %%
loan_ds.columns        # displays the columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_ds.dtypes # displays the types of the columns
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# **seperation of categorical and numerical columns**

# %%
categorical_columns=[]
numerical_columns=[]
for i in dict(loan_ds.dtypes):
    if dict(loan_ds.dtypes)[i]==object:
        categorical_columns.append(i)
    else:
        numerical_columns.append(i)
print(categorical_columns)
print(numerical_columns)
k=pd.DataFrame(numerical_columns,columns=["Numerical_column"])
k
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']
#     Numerical_column
# 0    ApplicantIncome
# 1  CoapplicantIncome
# 2         LoanAmount
# 3   Loan_Amount_Term
# 4     Credit_History

# %% [markdown]
# **identifying the missing values**

# %%
loan_ds.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# **Gender-column**

# %% [markdown]
# **as we know Gender is  categorical column so we need to replace missing values with mode**

# %%
mode_value=loan_ds["Gender"].mode()[0]
loan_ds["Gender"].fillna(mode_value,inplace=True)
loan_ds["Gender"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **we are replacing the 13 null values with the  mode value**

# %% [markdown]
# **Married-column**

# %%
mode_value1=loan_ds["Self_Employed"].mode()[0]
loan_ds["Self_Employed"].fillna(mode_value1,inplace=True)
loan_ds["Self_Employed"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Dependents**

# %%
loan_ds["Dependents"].replace(to_replace=['3+'],value=["4"],inplace=True)
mode_value11=loan_ds["Dependents"].mode()[0]
loan_ds["Dependents"].fillna(mode_value11,inplace=True)
loan_ds["Dependents"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **self employed**

# %%
mode_value2=loan_ds["Married"].mode()[0]
loan_ds["Married"].fillna(mode_value2,inplace=True)
loan_ds["Married"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Loan_amount**

# %%
mode_value3=loan_ds["LoanAmount"].median()
loan_ds["LoanAmount"].fillna(mode_value3,inplace=True)
loan_ds["LoanAmount"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Loan_Amount_Term**

# %%
mode_value3=loan_ds["Loan_Amount_Term"].median()
loan_ds["Loan_Amount_Term"].fillna(mode_value3,inplace=True)
loan_ds["Loan_Amount_Term"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Credit_History**

# %%
mode_value4=loan_ds["Credit_History"].median()
loan_ds["Credit_History"].fillna(mode_value4,inplace=True)
loan_ds["Credit_History"].isnull().sum()
# Out:
# 0

# %%
loan_ds.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# **so for every column we are successful fill the missing values**

# %% [markdown]
# **letus do the analysis for categorical-columns**

# %% [markdown]
# **1) gender**

# %%
loan_ds["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
loan_ds["Gender"].nunique()
# Out:
# 2

# %% [markdown]
# **creating a DataFrame for the Gender Column**

# %%
keys=loan_ds["Gender"].value_counts().keys()
values=loan_ds["Gender"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Gender","count"])
my_data
# Out:
#    Gender  count
# 0    Male    502
# 1  Female    112

# %%
keys=loan_ds["Gender"].value_counts().keys()
values=loan_ds["Gender"].value_counts().values
percentile=loan_ds["Gender"].value_counts(normalize=True).values*100
my_data=pd.DataFrame(zip(keys,values,percentile),columns=["Gender","count","percentile"])
my_data
# Out:
#    Gender  count  percentile
# 0    Male    502   81.758958
# 1  Female    112   18.241042

# %% [markdown]
# **2) Married**

# %%
keys=loan_ds["Married"].value_counts().keys()
values=loan_ds["Married"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Married","count"])
my_data
# Out:
#   Married  count
# 0     Yes    401
# 1      No    213

# %%
keys=loan_ds["Married"].value_counts().keys()
values=loan_ds["Married"].value_counts().values
percentile=loan_ds["Married"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Married","count","percentile"])
my_data_1
# Out:
#   Married  count  percentile
# 0     Yes    401   65.309446
# 1      No    213   34.690554

# %% [markdown]
# **Dependents**

# %%
keys=loan_ds["Dependents"].value_counts().keys()
values=loan_ds["Dependents"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Dependents","count"])
my_data
# Out:
#   Dependents  count
# 0          0    360
# 1          1    102
# 2          2    101
# 3          4     51

# %%
keys=loan_ds["Dependents"].value_counts().keys()
values=loan_ds["Dependents"].value_counts().values
percentile=loan_ds["Dependents"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Dependents","count","percentile"])
my_data_1
# Out:
#   Dependents  count  percentile
# 0          0    360   58.631922
# 1          1    102   16.612378
# 2          2    101   16.449511
# 3          4     51    8.306189

# %% [markdown]
# **Education**

# %%
keys=loan_ds["Education"].value_counts().keys()
values=loan_ds["Education"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Education","count"])
my_data
# Out:
#       Education  count
# 0      Graduate    480
# 1  Not Graduate    134

# %%
keys=loan_ds["Education"].value_counts().keys()
values=loan_ds["Education"].value_counts().values
percentile=loan_ds["Education"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Education","count","percentile"])
my_data_1
# Out:
#       Education  count  percentile
# 0      Graduate    480   78.175896
# 1  Not Graduate    134   21.824104

# %% [markdown]
# **Self_Employed**

# %%
keys11=loan_ds["Self_Employed"].value_counts().keys()
values11=loan_ds["Self_Employed"].value_counts().values
percentile=loan_ds["Self_Employed"].value_counts(normalize=True).values*100
my_data11=pd.DataFrame(zip(keys11,values11,percentile),columns=["Self_Employed","count","percentile"])
my_data11
# Out:
#   Self_Employed  count  percentile
# 0            No    532   86.644951
# 1           Yes     82   13.355049

# %%
keys=loan_ds["Self_Employed"].value_counts().keys()
values=loan_ds["Self_Employed"].value_counts().values
percentile=loan_ds["Self_Employed"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Self-Employed","count","percentile"])
my_data_1
# Out:
#   Self-Employed  count  percentile
# 0            No    532   86.644951
# 1           Yes     82   13.355049

# %% [markdown]
# **Property_Area**

# %%
keys=loan_ds["Property_Area"].value_counts().keys()
values=loan_ds["Property_Area"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Property_Area","count"])
my_data
# Out:
#   Property_Area  count
# 0     Semiurban    233
# 1         Urban    202
# 2         Rural    179

# %%
keys=loan_ds["Property_Area"].value_counts().keys()
values=loan_ds["Property_Area"].value_counts().values
percentile=loan_ds["Property_Area"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Property_Area","count","percentile"])
my_data_1
# Out:
#   Property_Area  count  percentile
# 0     Semiurban    233   37.947883
# 1         Urban    202   32.899023
# 2         Rural    179   29.153094

# %% [markdown]
# **Loan_Status**

# %%
keys=loan_ds["Loan_Status"].value_counts().keys()
values=loan_ds["Loan_Status"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Loan_Status","count"])
my_data
# Out:
#   Loan_Status  count
# 0           Y    422
# 1           N    192

# %%
keys=loan_ds["Loan_Status"].value_counts().keys()
values=loan_ds["Loan_Status"].value_counts().values
percentile=loan_ds["Loan_Status"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Loan_Status","count","percentile"])
my_data_1
# Out:
#   Loan_Status  count  percentile
# 0           Y    422   68.729642
# 1           N    192   31.270358

# %% [markdown]
# **now let us make this categorical analysis in graphs for easy understanding**

# %%
plt.figure(figsize=(16,16))
plt.subplot(3,3,1)
plt.title("Gender")
keys=loan_ds["Gender"].value_counts().keys()
values=loan_ds["Gender"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Gender","count"])
plt.xlabel("Gender")
plt.ylabel("count")

plt.bar("Gender","count",data=my_data,width=0.6,color=["#2ee634","#f0f719"])
plt.subplot(3,3,2)
plt.title("Married")
keys=loan_ds["Married"].value_counts().keys()
values=loan_ds["Married"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Married","count"],)
plt.bar("Married","count",data=my_data,color=["#2ee634","#f0f719"])
plt.xlabel("Married")
plt.ylabel("count")
plt.subplot(3,3,3)
keys=loan_ds["Dependents"].value_counts().keys()
values=loan_ds["Dependents"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Dependents","count"])
plt.bar("Dependents","count",data=my_data,color=["#2ee634","#f0f719"])
plt.title("Dependents")
plt.xlabel("Dependents")
plt.ylabel("count")
plt.subplot(3,3,4)
keys=loan_ds["Education"].value_counts().keys()
values=loan_ds["Education"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Education","count"])
plt.bar("Education","count",data=my_data,color=["#2ee634","#f0f719"])
plt.title("Education-column")
plt.xlabel("Education")
plt.ylabel("count")
plt.subplot(3,3,5)
keys=loan_ds["Self_Employed"].value_counts().keys()
values=loan_ds["Self_Employed"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Self_Employed","count"])
plt.bar("Self_Employed","count",data=my_data,color=["#2ee634","#f0f719"])
plt.title("self_Employed_column")
plt.xlabel("self_Employed")
plt.ylabel("count")
plt.subplot(3,3,6)
keys=loan_ds["Property_Area"].value_counts().keys()
values=loan_ds["Property_Area"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Property_Area","count"])
plt.bar("Property_Area","count",data=my_data,color=["#2ee634","#f0f719"])
plt.title("propert_area_column")
plt.xlabel("property_area")
plt.ylabel("count")
plt.subplot(3,3,7)
keys=loan_ds["Loan_Status"].value_counts().keys()
values=loan_ds["Loan_Status"].value_counts().values
my_data=pd.DataFrame(zip(keys,values),columns=["Loan_Status","count"])
plt.bar("Loan_Status","count",data=my_data,color=["#2ee634","#f0f719"])
plt.title("Loan_status")
plt.xlabel("Loan_status")
plt.ylabel("count")
plt.show()

# %% [markdown]
# **pie-chart**

# %%
plt.figure(figsize=(14,14))
plt.subplot(3,3,1)
plt.title("Gender")
keys=loan_ds["Gender"].value_counts().keys()
values=loan_ds["Gender"].value_counts().values
percentile=loan_ds["Gender"].value_counts(normalize=True).values*100
my_data=pd.DataFrame(zip(keys,values,percentile),columns=["Gender","count","percentile"])
plt.pie(x=percentile,autopct="% 1.2f%%",colors=["#2ee634","#f0f719"],labels=["Male","Female"])
plt.subplot(3,3,2)
plt.title("Married")
keys=loan_ds["Married"].value_counts().keys()
values=loan_ds["Married"].value_counts().values
percentile=loan_ds["Married"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Married","count","percentile"])
my_data_1
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719"],labels=["Married","Not-married"])
plt.subplot(3,3,3)
plt.title("Dependents")
keys=loan_ds["Dependents"].value_counts().keys()
values=loan_ds["Dependents"].value_counts().values
percentile=loan_ds["Dependents"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Dependents","count","percentile"])
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719","#0af7f3","#f79c0a"],labels=["0","1","2","4"])
plt.subplot(3,3,4)
plt.title("Education")
keys=loan_ds["Education"].value_counts().keys()
values=loan_ds["Education"].value_counts().values
percentile=loan_ds["Education"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Education","count","percentile"])
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719"],labels=["Graduate","Not-Graduate"])
plt.subplot(3,3,5)
plt.title("self-Employed")
keys=loan_ds["Self_Employed"].value_counts().keys()
values=loan_ds["Self_Employed"].value_counts().values
percentile=loan_ds["Self_Employed"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Education","count","percentile"])
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719"],labels=["No","Yes"])
plt.subplot(3,3,6)
keys=loan_ds["Property_Area"].value_counts().keys()
values=loan_ds["Property_Area"].value_counts().values
percentile=loan_ds["Property_Area"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Property_Area","count","percentile"])
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719","#0af7f3"],labels=["semi-urban","urban","rural"])
plt.subplot(3,3,7)
plt.title("Loan_status")
keys=loan_ds["Loan_Status"].value_counts().keys()
values=loan_ds["Loan_Status"].value_counts().values
percentile=loan_ds["Loan_Status"].value_counts(normalize=True).values*100
my_data_1=pd.DataFrame(zip(keys,values,percentile),columns=["Loan_Status","count","percentile"])
plt.pie(x=percentile,autopct="%1.2f%%",colors=["#2ee634","#f0f719"],labels=["Yes","No"])
plt.show()

# %% [markdown]
# **Numerical-analysis**

# %%
loan_ds.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# **histograms**

# %% [markdown]
# - **general we use histograms for analysis of the numerical columns**
# - **Let us draw the  hiostograms on the columns which we need to analysis**

# %%
plt.figure(figsize=(16,16))
plt.subplot(3,2,1)
plt.hist(loan_ds["ApplicantIncome"],bins=40)
plt.xlabel('Income')
plt.ylabel('applicants_count ')
plt.title('Histogram on applicant income')
 
plt.subplot(3,2,2)
plt.hist(loan_ds["CoapplicantIncome"],bins=40)
plt.xlabel('co-Income')
plt.ylabel('applicants_count ')
plt.title('Histogram on co-applicant income')
plt.subplot(3,2,3)
plt.hist(loan_ds["LoanAmount"],bins=40)
plt.xlabel('Loan_amount')
plt.ylabel('applicants_count ')
plt.title('Histogram on Loan amount')
plt.show()

# %% [markdown]
# - **as we see the applicants columns histogram we can se that data is skewed manner**
# - **so there may be outliers in the data so that's why the data  skewed manner**
# - **let us try to find really outliers are present in our data or not**

# %% [markdown]
# **finding the outliers of every column**

# %% [markdown]
# **ApplicantIncome**

# %%
loan_ds["ApplicantIncome"] #values of applicants colums
# Out:
# 0      5849
# 1      4583
# 2      3000
# 3      2583
# 4      6000
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 614, dtype: int64

# %%
loan_ds["ApplicantIncome"].describe()  #description of applicants column
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# **we  will use boxplot to detect wheteher outliers are present or not in the data**

# %% [markdown]
# **let us find the outliers using the boxplot**

# %%
q1=np.percentile(loan_ds["ApplicantIncome"],25)
q2=np.percentile(loan_ds["ApplicantIncome"],50)
q3=np.percentile(loan_ds["ApplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["ApplicantIncome"]>upper_bound
b=loan_ds["ApplicantIncome"]<lower_bound
c=a|b
len(loan_ds["ApplicantIncome"][c])
# Out:
# 50

# %% [markdown]
# - **so we have 50 outliers in our data**
# - **so we found 50 outliers in the data**
# - **we should remove the outliers**
# - **by using following methods we can remove the outliers**

# %% [markdown]
# - **method-1**
# -  **as the count of oultiers are less we will try to remove the oultiers**
# - **just we have 50 outliers we try to remove them**

# %%
q1=np.percentile(loan_ds["ApplicantIncome"],25)
q2=np.percentile(loan_ds["ApplicantIncome"],50)
q3=np.percentile(loan_ds["ApplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["ApplicantIncome"]<upper_bound
b=loan_ds["ApplicantIncome"]>lower_bound
k=loan_ds["ApplicantIncome"][a & b]
pd.DataFrame(k)
# Out:
#      ApplicantIncome
# 0               5849
# 1               4583
# 2               3000
# 3               2583
# 4               6000
# ..               ...
# 609             2900
# 610             4106
# 611             8072
# 612             7583
# 613             4583
#
# [564 rows x 1 columns]

# %% [markdown]
# **so we remove the oultiers as values which are greater than upperbound(q3+) and lower bound(q1-)**

# %% [markdown]
# - **method-2**
# - **let us try by imputing the median value**
# - **in this case we are replacing the outliers values with the median values**

# %%
l1=[]
q1=np.percentile(loan_ds["ApplicantIncome"],25)
q2=np.percentile(loan_ds["ApplicantIncome"],50)
q3=np.percentile(loan_ds["ApplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["ApplicantIncome"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
ApI=pd.DataFrame(l1,columns=["ApplicantIncome"])
ApI
# Out:
#      ApplicantIncome
# 0             5849.0
# 1             4583.0
# 2             3000.0
# 3             2583.0
# 4             6000.0
# ..               ...
# 609           2900.0
# 610           4106.0
# 611           8072.0
# 612           7583.0
# 613           4583.0
#
# [614 rows x 1 columns]

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("histogram on applicant-column  before removing outliers")

plt.hist(loan_ds["ApplicantIncome"],bins=40)

plt.subplot(2,2,2)
plt.title("boxplot on applicant-column  before removing outliers")
plt.boxplot(loan_ds["ApplicantIncome"],vert=False)
plt.subplot(2,2,3)
plt.title("histogram on applicant-column  after removing outliers")
q1=np.percentile(loan_ds["ApplicantIncome"],25)
q2=np.percentile(loan_ds["ApplicantIncome"],50)
q3=np.percentile(loan_ds["ApplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["ApplicantIncome"]<upper_bound
b=loan_ds["ApplicantIncome"]>lower_bound
k=loan_ds["ApplicantIncome"][a&b]
pd.DataFrame(k)
plt.hist(ApI,bins=40)

plt.subplot(2,2,4)
plt.title("boxplot on applicant-column  after removing outliers")
plt.boxplot(ApI,vert=False)
plt.show()

# %% [markdown]
# **now we will try to check the emperical rule of the new_colum of applicant income**

# %%
l1=[]
q1=np.percentile(loan_ds["ApplicantIncome"],25)
q2=np.percentile(loan_ds["ApplicantIncome"],50)
q3=np.percentile(loan_ds["ApplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["ApplicantIncome"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
loan_ds["new_ApplicantIncome"]=pd.DataFrame(l1,columns=["ApplicantIncome"])

# %% [markdown]
# **empircal-rule**

# %%
#68% of data should lie between

# %%
(68*614)/100
# Out:
# 417.52

# %%
x1=loan_ds["new_ApplicantIncome"].mean()
x2=loan_ds["new_ApplicantIncome"].std()
a=x1-1*x2
b=x1+1*x2
con1=loan_ds["new_ApplicantIncome"]>a
con2=loan_ds["new_ApplicantIncome"]<b
len(loan_ds["new_ApplicantIncome"][con1&con2])
# Out:
# 455

# %%
(95*614)/100
# Out:
# 583.3

# %%
x1=loan_ds["new_ApplicantIncome"].mean()
x2=loan_ds["new_ApplicantIncome"].std()
a=x1-2*x2
b=x1+2*x2
con1=loan_ds["new_ApplicantIncome"]>a
con2=loan_ds["new_ApplicantIncome"]<b
len(loan_ds["new_ApplicantIncome"][con1&con2])
# Out:
# 575

# %%
(99.7*614)/100
# Out:
# 612.158

# %%
x1=loan_ds["new_ApplicantIncome"].mean()
x2=loan_ds["new_ApplicantIncome"].std()
a=x1-3*x2
b=x1+3*x2
con1=loan_ds["new_ApplicantIncome"]>a
con2=loan_ds["new_ApplicantIncome"]<b
len(loan_ds["new_ApplicantIncome"][con1&con2])
# Out:
# 606

# %% [markdown]
# - **after removing the outliers we got values which are nearly of the empirical rule**
# - **so it is following empircal rule**
# - **now we will draw the distribution plot on the histogram after removing the outliers to check whether it looks like a normal distribution**

# %%
ax = ApI.plot.hist(bins=20, density=True, edgecolor='w')
xlim = ax.get_xlim()
ApI.plot.density(color='red', alpha=1, ax=ax) 
ax.set_xlim(xlim)
plt.show()

# %% [markdown]
# **The curve looks like a bell-shaped curve looks like it follows the normal distribution**

# %%
data1= len(loan_ds[((loan_ds["ApplicantIncome"]>=0)  & (loan_ds["ApplicantIncome"]<=10000))])
data2= len(loan_ds[((loan_ds["ApplicantIncome"]>10000)  & (loan_ds["ApplicantIncome"]<=20000))])
data3= len(loan_ds[((loan_ds["ApplicantIncome"]>20000)  & (loan_ds["ApplicantIncome"]<=30000))])
data4= len(loan_ds[((loan_ds["ApplicantIncome"]>30000)  & (loan_ds["ApplicantIncome"]<=40000))])
data5= len(loan_ds[((loan_ds["ApplicantIncome"]>40000)  & (loan_ds["ApplicantIncome"]<=50000))])
data6= len(loan_ds[((loan_ds["ApplicantIncome"]>50000)  & (loan_ds["ApplicantIncome"]<=60000))])
data7= len(loan_ds[((loan_ds["ApplicantIncome"]>60000)  & (loan_ds["ApplicantIncome"]<70000))])
data8= len(loan_ds[((loan_ds["ApplicantIncome"]>70000)  & (loan_ds["ApplicantIncome"]<=10000000))])
l=[data1,data2,data3,data4,data5,data6,data7,data8]
m=["0-10000","10000-20000","20000-30000","30000-40000","40000-50000","50000-60000","60000-70000","70000+"]
n=[]
for i in l:
    n.append((i/len(loan_ds))*100)
pd.DataFrame(zip(m,l,n),columns=["interval","count","percentile"])
# Out:
#       interval  count  percentile
# 0      0-10000    562   91.530945
# 1  10000-20000     40    6.514658
# 2  20000-30000      5    0.814332
# 3  30000-40000      4    0.651466
# 4  40000-50000      0    0.000000
# 5  50000-60000      1    0.162866
# 6  60000-70000      1    0.162866
# 7       70000+      1    0.162866

# %% [markdown]
# **normalization and standardization**

# %%
from sklearn.preprocessing import MinMaxScaler
MMS=MinMaxScaler()
loan_ds["ApplicantIncome_MMS"]=MMS.fit_transform(loan_ds[["ApplicantIncome"]])
print(loan_ds["ApplicantIncome_MMS"].min())
print(loan_ds["ApplicantIncome_MMS"].max())
# Out:
# 0.0
# 1.0000000000000002

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
loan_ds["ApplicantIncome_SS"]=SS.fit_transform(loan_ds[["ApplicantIncome"]])
print(loan_ds["ApplicantIncome_SS"].min())
print(loan_ds["ApplicantIncome_SS"].max())
# Out:
# -0.8606493225189494
# 12.38462278717314

# %%
loan_ds
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **now draw the boxplot**

# %%
plt.figure(figsize=(14,14))
plt.subplot(2,2,1)
plt.title("ApplicantIncome")
plt.boxplot(loan_ds["ApplicantIncome"],vert=False)

plt.subplot(2,2,2)
plt.title("ApplicantIncome with normalization")
plt.boxplot(loan_ds["ApplicantIncome_MMS"],vert=False)
plt.subplot(2,2,3)
plt.title("ApplicantIncome")
plt.boxplot(loan_ds["ApplicantIncome"],vert=False)
plt.subplot(2,2,4)
plt.title("ApplicantIncome with standardization")
plt.boxplot((loan_ds["ApplicantIncome_SS"]),vert=False)
plt.show()

# %% [markdown]
# **CoapplicantIncome**

# %%
loan_ds["CoapplicantIncome"]
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
#         ...
# 609       0.0
# 610       0.0
# 611     240.0
# 612       0.0
# 613       0.0
# Name: CoapplicantIncome, Length: 614, dtype: float64

# %%
loan_ds["CoapplicantIncome"].describe()
# Out:
# count      614.000000
# mean      1621.245798
# std       2926.248369
# min          0.000000
# 25%          0.000000
# 50%       1188.500000
# 75%       2297.250000
# max      41667.000000
# Name: CoapplicantIncome, dtype: float64

# %% [markdown]
# **finding the outliers**

# %%
q1=np.percentile(loan_ds["CoapplicantIncome"],25)
q2=np.percentile(loan_ds["CoapplicantIncome"],50)
q3=np.percentile(loan_ds["CoapplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["CoapplicantIncome"]>upper_bound
b=loan_ds["CoapplicantIncome"]<lower_bound
c=a|b
len(loan_ds["CoapplicantIncome"][c])
# Out:
# 18

# %% [markdown]
# **method-1**
# **remove outliers**

# %%
q1=np.percentile(loan_ds["CoapplicantIncome"],25)
q2=np.percentile(loan_ds["CoapplicantIncome"],50)
q3=np.percentile(loan_ds["CoapplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["CoapplicantIncome"]<upper_bound
b=loan_ds["CoapplicantIncome"]>lower_bound
c=a&b
caI=loan_ds["CoapplicantIncome"][c]
pd.DataFrame(caI)
# Out:
#      CoapplicantIncome
# 0                  0.0
# 1               1508.0
# 2                  0.0
# 3               2358.0
# 4                  0.0
# ..                 ...
# 609                0.0
# 610                0.0
# 611              240.0
# 612                0.0
# 613                0.0
#
# [596 rows x 1 columns]

# %% [markdown]
# **histogram and boxplot**

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("histogram before removing the outliers")
plt.hist(loan_ds["CoapplicantIncome"])
plt.subplot(2,2,2)
plt.title("box-plot before removing the outliers")
plt.boxplot(loan_ds["CoapplicantIncome"],vert=False)
plt.subplot(2,2,3)
plt.title("histogram after removing the outliers")
plt.hist(caI)
plt.subplot(2,2,4)
plt.title("box-plot after removing  the outliers")
plt.boxplot(caI,vert=False)
plt.show()

# %% [markdown]
# - **method-2**
# - **impute with the median values**

# %%
l1=[]
q1=np.percentile(loan_ds["CoapplicantIncome"],25)
q2=np.percentile(loan_ds["CoapplicantIncome"],50)
q3=np.percentile(loan_ds["CoapplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["CoapplicantIncome"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
loan_ds["ApI11"]=pd.DataFrame(l1,columns=["CoapplicantIncome"])
loan_ds["ApI11"]
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
#         ...
# 609       0.0
# 610       0.0
# 611     240.0
# 612       0.0
# 613       0.0
# Name: ApI11, Length: 614, dtype: float64

# %%
loan_ds["ApI11"].min()
# Out:
# 0.0

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("histogram before removing the outliers")
plt.hist(loan_ds["CoapplicantIncome"])
plt.subplot(2,2,2)
plt.title("box-plot before removing the outliers")
plt.boxplot(loan_ds["CoapplicantIncome"],vert=False)
plt.subplot(2,2,3)
plt.title("histogram after removing the outliers")
plt.hist(loan_ds["ApI11"])
plt.subplot(2,2,4)
plt.title("box-plot after removing  the outliers")
plt.boxplot(loan_ds["ApI11"],vert=False)
plt.show()

# %%
q1=np.percentile(loan_ds["CoapplicantIncome"],25)
q2=np.percentile(loan_ds["CoapplicantIncome"],50)
q3=np.percentile(loan_ds["CoapplicantIncome"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["CoapplicantIncome"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
loan_ds["new_CoapplicantIncome"]=pd.DataFrame(l1,columns=["CoapplicantIncome"])
loan_ds
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_ds["new_CoapplicantIncome"]
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
#         ...
# 609       0.0
# 610       0.0
# 611     240.0
# 612       0.0
# 613       0.0
# Name: new_CoapplicantIncome, Length: 614, dtype: float64

# %%
a=loan_ds["new_CoapplicantIncome"].mean()
b=loan_ds["new_CoapplicantIncome"].std()
c=a-1*b
d=a+1*b
con1=loan_ds["new_CoapplicantIncome"]>c
con2=loan_ds["new_CoapplicantIncome"]<d
len(loan_ds["new_CoapplicantIncome"][con1&con2])
# Out:
# 516

# %%
(68*614)/100
# Out:
# 417.52

# %%
a=loan_ds["new_CoapplicantIncome"].mean()
b=loan_ds["new_CoapplicantIncome"].std()
c=a-2*b
d=a+2*b
con1=loan_ds["new_CoapplicantIncome"]>c
con2=loan_ds["new_CoapplicantIncome"]<d
len(loan_ds["new_CoapplicantIncome"][con1&con2])
# Out:
# 575

# %%
(95*614)/100
# Out:
# 583.3

# %%
a=loan_ds["new_CoapplicantIncome"].mean()
b=loan_ds["new_CoapplicantIncome"].std()
c=a-3*b
d=a+3*b
con1=loan_ds["new_CoapplicantIncome"]>c
con2=loan_ds["new_CoapplicantIncome"]<d
len(loan_ds["new_CoapplicantIncome"][con1&con2])
# Out:
# 608

# %%
(99.7*614)/100
# Out:
# 612.158

# %% [markdown]
# **normalization and standardazation**

# %%
from sklearn.preprocessing import MinMaxScaler
MMS=MinMaxScaler()
loan_ds["CoapplicantIncome_MMS"]=MMS.fit_transform(loan_ds[["CoapplicantIncome"]])
print(loan_ds["CoapplicantIncome_MMS"].min())
print(loan_ds["CoapplicantIncome_MMS"].max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
loan_ds["new_CoapplicantIncome_SS"]=SS.fit_transform(loan_ds[["CoapplicantIncome"]])
print(loan_ds["new_CoapplicantIncome_SS"].min())
print(loan_ds["new_CoapplicantIncome_SS"].max())
# Out:
# -0.5544873301529852
# 13.696173250494041

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("co-applicant income ")
plt.boxplot(loan_ds["CoapplicantIncome"],vert=False)
plt.subplot(2,2,2)
plt.title("co-applicant income  with normalization")
plt.boxplot(loan_ds["CoapplicantIncome_MMS"],vert=False)
plt.subplot(2,2,3)
plt.title("co-applicant income ")
plt.boxplot(loan_ds["CoapplicantIncome"],vert=False)
plt.subplot(2,2,4)
plt.title("co-applicant income  with standardzation")
plt.boxplot(loan_ds["new_CoapplicantIncome_SS"],vert=False)
plt.show()

# %%
loan_ds["LoanAmount"]
# Out:
# 0      128.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
loan_ds["LoanAmount"].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %% [markdown]
# **finding the outliers**

# %%
q1=np.percentile(loan_ds["LoanAmount"],25)
q2=np.percentile(loan_ds["LoanAmount"],50)
q3=np.percentile(loan_ds["LoanAmount"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["LoanAmount"]>upper_bound
b=loan_ds["LoanAmount"]<lower_bound
c=a|b
len(loan_ds["LoanAmount"][c])
# Out:
# 41

# %% [markdown]
# - **method-1**
# - **remove 41 outliers**

# %%
q1=np.percentile(loan_ds["LoanAmount"],25)
q2=np.percentile(loan_ds["LoanAmount"],50)
q3=np.percentile(loan_ds["LoanAmount"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
a=loan_ds["LoanAmount"]<upper_bound
b=loan_ds["LoanAmount"]>lower_bound
c=a&b
LA=loan_ds["LoanAmount"][c]
pd.DataFrame(LA)
# Out:
#      LoanAmount
# 0         128.0
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [573 rows x 1 columns]

# %%
loan_ds["LoanAmount"].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("histogram before removing the outliers")
plt.hist(loan_ds["LoanAmount"],bins=40)
plt.subplot(2,2,2)
plt.title("box-plot before removing the outliers")
plt.boxplot(loan_ds["LoanAmount"],vert=False)
plt.subplot(2,2,3)
plt.title("histogram after removing the outliers")
plt.hist(LA,bins=40)
plt.subplot(2,2,4)
plt.title("box-plot after removing the outliers")
plt.boxplot(LA,vert=False)
plt.show()

# %% [markdown]
# **method-2 with median**

# %%
l1=[]
q1=np.percentile(loan_ds["LoanAmount"],25)
q2=np.percentile(loan_ds["LoanAmount"],50)
q3=np.percentile(loan_ds["LoanAmount"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["LoanAmount"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
LA1=pd.DataFrame(l1,columns=["LoanAmount"])
LA1
# Out:
#      LoanAmount
# 0         128.0
# 1         128.0
# 2          66.0
# 3         120.0
# 4         141.0
# ..          ...
# 609        71.0
# 610        40.0
# 611       253.0
# 612       187.0
# 613       133.0
#
# [614 rows x 1 columns]

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("histogram before removing the outliers")
plt.hist(loan_ds["LoanAmount"],bins=40)
plt.subplot(2,2,2)
plt.title("box-plot before removing the outliers")
plt.boxplot(loan_ds["LoanAmount"],vert=False)

plt.subplot(2,2,3)
plt.title("histogram after replacing outliers with median value ")

l1=[]
q1=np.percentile(loan_ds["LoanAmount"],25)
q2=np.percentile(loan_ds["LoanAmount"],50)
q3=np.percentile(loan_ds["LoanAmount"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["LoanAmount"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
LA1=pd.DataFrame(l1,columns=["LoanAmount"])
LA1
plt.hist(LA1,bins=40)
plt.subplot(2,2,4)
plt.title("box-plot after replacing outliers with median value ")
l1=[]
q1=np.percentile(loan_ds["LoanAmount"],25)
q2=np.percentile(loan_ds["LoanAmount"],50)
q3=np.percentile(loan_ds["LoanAmount"],75)
iqr=q3-q1
upper_bound=q3+1.5*(iqr)
lower_bound=q1-1.5*(iqr)
for i in loan_ds["LoanAmount"]:
    if i>upper_bound or i<lower_bound:
        l1.append(q2)
    else:
        l1.append(i)
LA1=pd.DataFrame(l1,columns=["LoanAmount"])
LA1
plt.boxplot(LA1,vert=False)
plt.show()

# %%
#based on histogram  before removing the outliers
a=len(loan_ds[(loan_ds["LoanAmount"]>0) & (loan_ds["LoanAmount"]<=100)])
b=len(loan_ds[(loan_ds["LoanAmount"]>100) & (loan_ds["LoanAmount"]<=200)])
c=len(loan_ds[(loan_ds["LoanAmount"]>200) & (loan_ds["LoanAmount"]<=300)])
d=len(loan_ds[(loan_ds["LoanAmount"]>300) & (loan_ds["LoanAmount"]<=400)])
e=len(loan_ds[(loan_ds["LoanAmount"]>400) & (loan_ds["LoanAmount"]<=500)])
f=len(loan_ds[(loan_ds["LoanAmount"]>500) & (loan_ds["LoanAmount"]<=600)])
g=len(loan_ds[(loan_ds["LoanAmount"]>600) & (loan_ds["LoanAmount"]<=700)])

l=["0-100","100-200","200-300","300-400","400-500","500-600","600-700"]
m=[a,b,c,d,e,f,g]
k=[]
for i in m:
    k.append((i*100)/len(loan_ds["LoanAmount"]))
pd.DataFrame(zip(l,m,k),columns=["interval","count","percentile"])
# Out:
#   interval  count  percentile
# 0    0-100    154   25.081433
# 1  100-200    380   61.889251
# 2  200-300     51    8.306189
# 3  300-400     15    2.442997
# 4  400-500      9    1.465798
# 5  500-600      3    0.488599
# 6  600-700      2    0.325733

# %%
ax = LA1.plot.hist(bins=20, density=True, edgecolor='w')

# Save default x-axis limits for final formatting because the pandas kde
# plot uses much wider limits which usually decreases readability
xlim = ax.get_xlim()

# Plot pandas KDE
LA1.plot.density(color='red', alpha=1, ax=ax) # same as df['var'].plot.kde()

# Reset x-axis limits and edit legend and add title
ax.set_xlim(xlim)


plt.show()

# %% [markdown]
# **Normalization and standardization**

# %%
from sklearn.preprocessing import MinMaxScaler
MMS=MinMaxScaler()
loan_ds["LoanAmount_MMS"]=MMS.fit_transform(loan_ds[["LoanAmount"]])
print(loan_ds["LoanAmount_MMS"].min())
print(loan_ds["LoanAmount_MMS"].max())
# Out:
# 0.0
# 1.0

# %%
from sklearn.preprocessing import StandardScaler
SS=StandardScaler()
loan_ds["LoanAmount_SS"]=SS.fit_transform(loan_ds[["LoanAmount"]])
print(loan_ds["LoanAmount_SS"].min())
print(loan_ds["LoanAmount_SS"].max())
# Out:
# -1.627255298188799
# 6.59514560674599

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("Loan amount")
plt.boxplot(loan_ds["LoanAmount"],vert=False)
plt.subplot(2,2,2)
plt.title("Loan amount using Normalization")
plt.boxplot(loan_ds["LoanAmount_MMS"],vert=False)
plt.subplot(2,2,3)
plt.title("Loan amount")
plt.boxplot(loan_ds["LoanAmount"],vert=False)
plt.subplot(2,2,4)
plt.title("Loan amount using Standardazation")
plt.boxplot(loan_ds["LoanAmount_SS"],vert=False)
plt.show()

# %%
loan_ds
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **bivarient and mutlivarient analysis**

# %% [markdown]
# **let us do on the 2 diffrent columns**

# %%
bdata=pd.crosstab(loan_ds["Gender"],loan_ds["Loan_Status"])
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
one=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Loan_Status"]=="Y")])
two=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Loan_Status"]=="N")])
Three=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Loan_Status"]=="Y")])
Four=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Loan_Status"]=="N")])
l1=[one,Three]
l2=[two,Four]
l3=[(one*100)/len(loan_ds),(Three*100)/len(loan_ds)]
l4=[(two*100)/len(loan_ds),(Four*100)/len(loan_ds)]
pd.DataFrame(zip(l1,l2,l3,l4),columns=["Male","Female","male_percent","Female_percent"],index=["yes","No"])
# Out:
#      Male  Female  male_percent  Female_percent
# yes   347     155     56.514658       25.244300
# No     75      37     12.214984        6.026059

# %%
bdata=pd.crosstab(loan_ds["Education"],loan_ds["Loan_Status"])

# %%
bdata=pd.crosstab(loan_ds["Education"],loan_ds["Loan_Status"])
bdata.plot(kind="bar")
plt.show()

# %%
one=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Loan_Status"]=="Y")])
two=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Loan_Status"]=="N")])
Three=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Loan_Status"]=="Y")])
Four=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Loan_Status"]=="N")])
l1=[one,Three]
l2=[two,Four]
l3=[(one*100)/len(loan_ds),(Three*100)/len(loan_ds)]
l4=[(two*100)/len(loan_ds),(Four*100)/len(loan_ds)]
pd.DataFrame(zip(l1,l2,l3,l4),columns=["Graduate","Not_graduate","G_percent","NG_percent"],index=["yes","No"])
# Out:
#      Graduate  Not_graduate  G_percent  NG_percent
# yes       340           140  55.374593   22.801303
# No         82            52  13.355049    8.469055

# %%
bdata=pd.crosstab(loan_ds["Self_Employed"],loan_ds["Loan_Status"])
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Self_Employed'>

# %%
one=len(loan_ds[(loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="Y")])
two=len(loan_ds[(loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="N")])
Three=len(loan_ds[(loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="Y")])
Four=len(loan_ds[(loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="N")])
l1=[one,Three]
l2=[two,Four]
l3=[(one*100)/len(loan_ds),(Three*100)/len(loan_ds)]
l4=[(two*100)/len(loan_ds),(Four*100)/len(loan_ds)]
pd.DataFrame(zip(l1,l2,l3,l4),columns=["self-employed","Not_self_employed","SE_percent","NSE_percent"],index=["yes","No"])
# Out:
#      self-employed  Not_self_employed  SE_percent  NSE_percent
# yes             56                 26    9.120521     4.234528
# No             366                166   59.609121    27.035831

# %%
l1=loan_ds["Gender"]
l2=loan_ds["Married"]
l3=loan_ds["Loan_Status"]
x=[l1,l2]
bdata=pd.crosstab(l3,x)
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
a=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Married"]=="Yes") & (loan_ds["Loan_Status"]=="Y")])
b=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Married"]=="No") & (loan_ds["Loan_Status"]=="Y")])
c=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Married"]=="Yes") & (loan_ds["Loan_Status"]=="Y")])
d=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Married"]=="No") & (loan_ds["Loan_Status"]=="Y")])
a1=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Married"]=="Yes") & (loan_ds["Loan_Status"]=="N")])
b1=len(loan_ds[(loan_ds["Gender"]=="Male") & (loan_ds["Married"]=="No") & (loan_ds["Loan_Status"]=="N")])
c1=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Married"]=="Yes") & (loan_ds["Loan_Status"]=="N")])
d1=len(loan_ds[(loan_ds["Gender"]=="Female") & (loan_ds["Married"]=="No") & (loan_ds["Loan_Status"]=="N")])
l1=[a,b,c,d]
l2=[a1,b1,c1,d1]
l3=[]
l4=[]
for i in l1:
    l3.append((i*100)/len(loan_ds))
for i in l2:
    l4.append((i*100)/len(loan_ds))
    
pd.DataFrame(zip(l1,l2,l3,l4),columns=["yes","no","yes_%","no_%"],index=["MY","MN","FY","FN"])
# Out:
#     yes   no      yes_%       no_%
# MY  264  105  42.996743  17.100977
# MN   83   50  13.517915   8.143322
# FY   24    8   3.908795   1.302932
# FN   51   29   8.306189   4.723127

# %%
l1=loan_ds["Education"]
l2=loan_ds["Self_Employed"]
l3=loan_ds["Loan_Status"]
x=[l1,l2]
bdata=pd.crosstab(l3,x)
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
a=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="Y")])
b=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="Y")])
c=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="Y")])
d=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="Y")])
a1=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="N")])
b1=len(loan_ds[(loan_ds["Education"]=="Graduate") & (loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="N")])
c1=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Self_Employed"]=="Yes") & (loan_ds["Loan_Status"]=="N")])
d1=len(loan_ds[(loan_ds["Education"]=="Not Graduate") & (loan_ds["Self_Employed"]=="No") & (loan_ds["Loan_Status"]=="N")])

l1=[a,b,c,d]
l2=[a1,b1,c1,d1]
l3=[]
l4=[]
for i in l1:
    l3.append((i*100)/len(loan_ds))
for i in l2:
    l4.append((i*100)/len(loan_ds))
    
pd.DataFrame(zip(l1,l2,l3,l4),columns=["yes","no","yes_%","no_%"],index=["GY","GN","NGY","NGN"])
# Out:
#      yes   no      yes_%       no_%
# GY    46   19   7.491857   3.094463
# GN   294  121  47.882736  19.706840
# NGY   10    7   1.628664   1.140065
# NGN   72   45  11.726384   7.328990

# %%
l1=loan_ds["Gender"]
l2=loan_ds["Married"]
l4=loan_ds["Education"]
l3=loan_ds["Loan_Status"]
x=[l1,l2,l4]
bdata=pd.crosstab(l3,x)
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
crosstb4 = pd.crosstab(index = [loan_ds["Loan_Status"],loan_ds["Gender"]],\
                      columns = [ loan_ds["Married"],loan_ds["Education"]] , \
                      normalize=True, margins = True, \
                      ) *100

crosstb4.astype(str).applymap(lambda x:x + '%')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_18824\2958084707.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   crosstb4.astype(str).applymap(lambda x:x + '%')
# Married                              No                       \
# Education                      Graduate         Not Graduate
# Loan_Status Gender
# N           Female   3.908794788273615%  0.8143322475570033%
#             Male     6.188925081433225%  1.9543973941368076%
# Y           Female   6.840390879478828%  1.4657980456026058%
#             Male    10.423452768729643%  3.0944625407166124%
# All                  27.36156351791531%    7.32899022801303%
#
# Married                             Yes                        \
# Education                      Graduate          Not Graduate
# Loan_Status Gender
# N           Female  1.1400651465798046%  0.16286644951140067%
#             Male    11.563517915309445%    5.537459283387622%
# ...

# %%
crosstb4 = pd.crosstab(index = [loan_ds["Loan_Status"],loan_ds["Gender"]],\
                      columns = [ loan_ds["Married"],loan_ds["Education"]] , \
                       margins = True, \
                      ) 

crosstb4.astype(str).applymap(lambda x:x)
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_18824\4216581888.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   crosstb4.astype(str).applymap(lambda x:x)
# Married                  No                   Yes               All
# Education          Graduate Not Graduate Graduate Not Graduate
# Loan_Status Gender
# N           Female       24            5        7            1   37
#             Male         38           12       71           34  155
# Y           Female       42            9       19            5   75
#             Male         64           19      215           49  347
# All                     168           45      312           89  614

# %%
crosstb4 = pd.crosstab(index = [loan_ds["Loan_Status"],loan_ds["Property_Area"]],\
                      columns = [loan_ds["Self_Employed"],loan_ds["Education"]] , \
                       margins = True, \
                      ) 

crosstb4.astype(str).applymap(lambda x:x)
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_18824\4189030214.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   crosstb4.astype(str).applymap(lambda x:x)
# Self_Employed                   No                   Yes               All
# Education                 Graduate Not Graduate Graduate Not Graduate
# Loan_Status Property_Area
# N           Rural               40           20        7            2   69
#             Semiurban           39            8        4            3   54
#             Urban               42           17        8            2   69
# Y           Rural               70           23       14            3  110
#             Semiurban          123           31       21            4  179
#             Urban              101           18       11            3  133
# All                            415          117       65           17  614

# %%
l4=loan_ds["Gender"]
l5=loan_ds["Married"]
l6=loan_ds["Education"]

l3=loan_ds["Loan_Status"]
x=[l4,l5,l6]
bdata=pd.crosstab(l3,x,margins=False)
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
plt.figure(figsize=(8,8))
l4=loan_ds["Education"]
l5=loan_ds["Self_Employed"]
l6=loan_ds["Property_Area"]

l3=loan_ds["Loan_Status"]
x=[l4,l5,l6]
bdata=pd.crosstab(l3,x)
bdata.plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
crosstb4 = pd.crosstab(index = [loan_ds["Loan_Status"],loan_ds["Education"]],\
                      columns = [loan_ds["Self_Employed"],loan_ds["Property_Area"]] , \
                      normalize=True, margins = True, \
                      ) *100

crosstb4.astype(str).applymap(lambda x:x +'%')
# Out:
# C:\Users\Venkatesh\AppData\Local\Temp\ipykernel_18824\493824393.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   crosstb4.astype(str).applymap(lambda x:x +'%')
# Self_Employed                              No                       \
# Property_Area                           Rural            Semiurban
# Loan_Status Education
# N           Graduate       6.514657980456026%   6.351791530944626%
#             Not Graduate   3.257328990228013%  1.3029315960912053%
# Y           Graduate      11.400651465798045%   20.03257328990228%
#             Not Graduate  3.7459283387622153%   5.048859934853421%
# All                         24.9185667752443%   32.73615635179153%
#
# Self_Employed                                                   Yes  \
# Property_Area                           Urban                 Rural
# Loan_Status Education
# N           Graduate       6.840390879478828%   1.1400651465798046%
# ...

# %% [markdown]
# **scatter-plot**

# %%
plt.scatter(loan_ds["CoapplicantIncome"],loan_ds["LoanAmount"])

# %%
plt.scatter(loan_ds["ApplicantIncome"],loan_ds["LoanAmount"])

# %%
#loan_ds.drop(Credit_History,axis=1)
corr_data=loan_ds.corr(numeric_only=True)
corr_data
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.565181
# CoapplicantIncome        -0.116605           1.000000    0.189218
# LoanAmount                0.565181           0.189218    1.000000
# Loan_Amount_Term         -0.046531          -0.059383    0.036960
# Credit_History           -0.018615           0.011134   -0.000607
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.046531       -0.018615
# CoapplicantIncome         -0.059383        0.011134
# LoanAmount                 0.036960       -0.000607
# Loan_Amount_Term           1.000000       -0.004705
# Credit_History            -0.004705        1.000000

# %%
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
l1=[]
for i in corr_data.values:
      for j in i:
          if j!=1:
              l1.append(j)
l1.sort()
k11=l1[-2:]
print(k11)
l1=[]
for i in corr_data.values:
      for j in i:
          if j!=1:
              l1.append(j)
l1.sort()
k22=l1[:2]
print(k22)
# Out:
# [0.5651805176233123, 0.5651805176233123]
# [-0.11660458122889955, -0.11660458122889955]

# %%
l1=[]
for i in corr_data.values:
      for j in i:
          if j!=1:
              l1.append(j)

k=sorted(set(l1),reverse=True)
k1=k[:2]
print(k1)
l1=[]
for i in corr_data.values:
      for j in i:
          if j!=1:
              l1.append(j)

k=sorted(set(l1),reverse=False)
k2=k[:2]
print(k2)
# Out:
# [0.5709090389885663, 0.18861940442311742]
# [-0.11660458122889955, -0.059878008731631405]

# %%
plt.scatter(k1,k2)

# %% [markdown]
# **converting categorical into numerical**

# %% [markdown]
# - **it is  very important to convert the categorical columns into numerical columns**
# - **Machine will only understand the numbers only not names so in order to train ml models we need to convert categorical to numerical columns**

# %%
loan_ds.dtypes
# Out:
# Loan_ID                      object
# Gender                       object
# Married                      object
# Dependents                   object
# Education                    object
# Self_Employed                object
# ApplicantIncome               int64
# CoapplicantIncome           float64
# LoanAmount                  float64
# Loan_Amount_Term            float64
# Credit_History              float64
# Property_Area                object
# Loan_Status                  object
# new_ApplicantIncome         float64
# ApplicantIncome_MMS         float64
# ApplicantIncome_SS          float64
# new_CoapplicantIncome       float64
# CoapplicantIncome_MMS       float64
# new_CoapplicantIncome_SS    float64
# dtype: object

# %% [markdown]
# **Gender**

# %%
loan_ds["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# **so we can use here np.where as it is binary conditions**

# %%
x=loan_ds["Gender"]=="Male"
loan_ds["Gender"]=np.where(a,1,0)
loan_ds
# Out:
#       Loan_ID  Gender Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1      No           0          1              0
# 1    LP001003       1     Yes           1          1              0
# 2    LP001005       1     Yes           0          1              1
# 3    LP001006       1     Yes           0          0              0
# 4    LP001008       1      No           0          1              0
# ..        ...     ...     ...         ...        ...            ...
# 609  LP002978       1      No           0          1              0
# 610  LP002979       1     Yes           3          1              0
# 611  LP002983       1     Yes           1          1              0
# 612  LP002984       1     Yes           2          1              0
# 613  LP002990       1      No           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# ...

# %% [markdown]
# **married**

# %%
loan_ds["Married"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x=loan_ds["Married"]=="Yes"
loan_ds["Married"]=np.where(a,1,0)
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       1        1           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **Dependents**

# %%
loan_ds["Dependents"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 614 entries, 0 to 613
# Series name: Dependents
# Non-Null Count  Dtype
# --------------  -----
# 614 non-null    object
# dtypes: object(1)
# memory usage: 4.9+ KB

# %%
loan_ds["Dependents"].unique()
# Out:
# array(['0', '1', '2', '4'], dtype=object)

# %%
loan_ds["Dependents"].nunique()
# Out:
# 4

# %% [markdown]
# - **here np.where cant used**
# - **map can use but we have write code manullay for 4 values**
# - **so we move to Label encoder**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_ds["Dependents"]=le.fit_transform(loan_ds["Dependents"])
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          1              0
# 1    LP001003       1        1           1          1              0
# 2    LP001005       1        1           0          1              1
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          1              0
# 610  LP002979       1        1           3          1              0
# 611  LP002983       1        1           1          1              0
# 612  LP002984       1        1           2          1              0
# 613  LP002990       1        1           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_ds["Dependents"].dtype
# Out:
# dtype('int64')

# %%
#succesful converted to numeric

# %%
loan_ds["Education"].dtype
# Out:
# dtype('O')

# %%
loan_ds["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %% [markdown]
# **so here we have 2 possiblities so we can go with the np.where condition or map**

# %%
x=loan_ds["Education"]=='Graduate'
loan_ds["Education"]=np.where(x,1,0)
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              1
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       1        1           0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **self_employee**

# %%
loan_ds["Self_Employed"].dtype
# Out:
# dtype('O')

# %%
loan_ds["Self_Employed"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
x=loan_ds["Self_Employed"]=='Yes'
loan_ds["Self_Employed"]=np.where(x,1,0)
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       1        1           0          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **Property_Area**

# %%
loan_ds["Property_Area"].dtype
# Out:
# dtype('O')

# %%
loan_ds["Property_Area"].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %% [markdown]
# **using Label Encoder is best**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
loan_ds["Property_Area"]=le.fit_transform(loan_ds["Property_Area"])

# %%
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       0        0           0          1              0
# 1    LP001003       0        0           1          1              0
# 2    LP001005       0        0           0          1              1
# 3    LP001006       0        0           0          0              0
# 4    LP001008       0        0           0          1              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       0        0           0          1              0
# 610  LP002979       0        0           3          1              0
# 611  LP002983       0        0           1          1              0
# 612  LP002984       0        0           2          1              0
# 613  LP002990       0        0           0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# **Loan_Status**

# %%
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       1        1           0          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
x=loan_ds["Loan_Status"]=="Y"
loan_ds["Loan_Status"]=np.where(a,1,0)
loan_ds
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001002       1        1           0          0              0
# 1    LP001003       1        1           1          0              0
# 2    LP001005       1        1           0          0              0
# 3    LP001006       1        1           0          0              0
# 4    LP001008       1        1           0          0              0
# ..        ...     ...      ...         ...        ...            ...
# 609  LP002978       1        1           0          0              0
# 610  LP002979       1        1           3          0              0
# 611  LP002983       1        1           1          0              0
# 612  LP002984       1        1           2          0              0
# 613  LP002990       1        1           0          0              0
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_ds.drop(["Loan_ID","ApI11","new_CoapplicantIncome","new_CoapplicantIncome_SS","CoapplicantIncome_MMS","new_ApplicantIncome","ApplicantIncome_MMS","ApplicantIncome_SS"],axis=1)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              0             3000
# 3         1        1           0          0              0             2583
# 4         1        1           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       1        1           0          0              0             2900
# 610       1        1           3          0              0             4106
# 611       1        1           1          0              0             8072
# 612       1        1           2          0              0             7583
# 613       1        1           0          0              0             4583
#
# ...
